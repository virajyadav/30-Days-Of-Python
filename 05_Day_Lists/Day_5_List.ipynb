# %% [markdown]
# ## List
# Join the following lists:
#
# front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
# back_end = ['Node','Express', 'MongoDB']
# * After joining the lists in question 26. Copy the joined list and assign it to a variable full_stack, then insert Python and SQL after Redux.

# %%
front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
back_end = ['Node','Express', 'MongoDB']

# %%
full_stack = front_end + back_end

# %%
full_stack
# Out:
# ['HTML',
#  'CSS',
#  'JS',
#  'React',
#  'Redux',
#  'Python',
#  'SQL',
#  'Node',
#  'Express',
#  'MongoDB']

# %%
full_stack.insert(5,"Python")

# %%
full_stack.insert(6, "SQL")

# %% [markdown]
# * Sort the list and find the min and max age
# * Add the min age and the max age again to the list
# * Find the median age (one middle item or two middle items divided by two)
# * Find the average age (sum of all items divided by their number )
# * Find the range of the ages (max minus min)
# * Compare the value of (min - average) and (max - average), use abs() method

# %%
ages = [19, 22, 19, 24, 20, 25, 26, 24, 25, 24]

# %%
ages.sort()

# %%
ages
# Out:
# [19, 19, 20, 22, 24, 24, 24, 25, 25, 26]

# %%
min_age = ages[0]
max_age = ages[-1]

# %%
min(ages)
# Out:
# 19

# %%
max(ages)
# Out:
# 26

# %%
middle_index = len(ages) // 2
middle_index
# Out:
# 5

# %%
len(ages)
# Out:
# 10

# %%
def get_middle_index(ages):
    middle_index = len(ages) // 2
    if len(ages) % 2 == 1:
        return(ages[middle_index])
    else:
        return(ages[middle_index-1],ages[middle_index])

# %% [markdown]
# ## Division
# * / for float values use for math and formula
# * // for int values ; use for indexing , chunking , pagination, batch

# %%
avg_ages = sum(ages) // len(ages)
avg_ages
# Out:
# 22.8

# %%
range_of_ages = max(ages) - min(ages)
range_of_ages
# Out:
# 7

# %% [markdown]
# * Find the middle country(ies) in the countries list
# * Divide the countries list into two equal lists if it is even if not one more country for the first half.
# .
# * Unpack the first three countries and the rest as scandic countries.

# %%
countires = ['China', 'Russia', 'USA', 'Finland', 'Sweden', 'Norway', 'Denmark']

# %%
n = len(countires)
n
# Out:
# 7

# %%
get_middle_index(countires)
# Out:
# 'Finland'

# %%
mid = (n+1) // 2
mid
# Out:
# 4

# %%
first_half = countires[:mid]
second_half = countires[mid:]

# %%
first_half,second_half
# Out:
# (['China', 'Russia', 'USA', 'Finland'], ['Sweden', 'Norway', 'Denmark'])

# %%
c1, c2, c3, *scandic = countires

# %%
scandic
# Out:
# ['Finland', 'Sweden', 'Norway', 'Denmark']
